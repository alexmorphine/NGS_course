# %%
import numpy as np
import pandas as pd

# %%
# !bwa index data/MG1655-K12.first400K.fasta
# !bwa mem data/MG1655-K12.first400K.fasta data/ecoli_400K_err_1.fastq data/ecoli_400K_err_2.fastq > ecoli_400.sam
# Out:
# [bwa_index] Pack FASTA... 0.00 sec
# [bwa_index] Construct BWT for the packed sequence...
# [bwa_index] 0.08 seconds elapse.
# [bwa_index] Update BWT... 0.00 sec
# [bwa_index] Pack forward-only FASTA... 0.00 sec
# [bwa_index] Construct SA from BWT and Occ... 0.04 sec
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa index data/MG1655-K12.first400K.fasta
# [main] Real time: 0.141 sec; CPU: 0.125 sec
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 100000 sequences (10000000 bp)...
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48301, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.27, 10.16)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.673 CPU sec, 3.598 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48357, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.22, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.808 CPU sec, 3.650 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48345, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.35, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.442 CPU sec, 3.320 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48337, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.37, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.406 CPU sec, 3.287 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48338, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.35, 10.16)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.408 CPU sec, 3.281 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48367, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.33, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.462 CPU sec, 3.316 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48287, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 221)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (179, 249)
# [M::mem_pestat] mean and std.dev: (214.23, 10.14)
# [M::mem_pestat] low and high boundaries for proper pairs: (165, 263)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.965 CPU sec, 3.851 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48328, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.36, 10.16)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.986 CPU sec, 3.742 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48359, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.37, 10.08)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.499 CPU sec, 3.345 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48323, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.38, 10.12)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.566 CPU sec, 3.413 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48276, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.26, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.533 CPU sec, 3.393 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48231, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.27, 10.13)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.524 CPU sec, 3.394 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48187, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.35, 10.14)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.612 CPU sec, 3.507 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48265, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.41, 10.16)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.542 CPU sec, 3.407 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48287, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.24, 10.17)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.396 CPU sec, 3.275 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48307, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.33, 10.12)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.346 CPU sec, 3.214 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48303, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.40, 10.17)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.775 CPU sec, 3.617 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48393, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.40, 10.14)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 5.024 CPU sec, 4.799 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48320, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.32, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 5.027 CPU sec, 4.875 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48377, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.26, 10.16)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.487 CPU sec, 3.340 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48307, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.31, 10.13)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.392 CPU sec, 3.271 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48322, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 221)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (179, 249)
# [M::mem_pestat] mean and std.dev: (214.27, 10.06)
# [M::mem_pestat] low and high boundaries for proper pairs: (165, 263)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.205 CPU sec, 3.067 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48361, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.23, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.227 CPU sec, 3.095 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48350, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.35, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.320 CPU sec, 3.178 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48319, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.32, 10.16)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.156 CPU sec, 3.024 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48334, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.24, 10.13)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.161 CPU sec, 3.026 real sec
# [M::process] read 63204 sequences (6320400 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48289, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.28, 10.14)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.226 CPU sec, 3.128 real sec
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 30551, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.31, 10.19)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 63204 reads in 2.005 CPU sec, 1.915 real sec
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem data/MG1655-K12.first400K.fasta data/ecoli_400K_err_1.fastq data/ecoli_400K_err_2.fastq
# [main] Real time: 95.518 sec; CPU: 99.307 sec

# %%
def cnt_err_del(sam, fasta, n_as_error=False, start_positions=None):

    with open(fasta) as file:
        reference = ''.join([line.strip() for line in file if not line.startswith('>')])
    ref_length = len(reference)
    
    
    n_errors, n_deletions = {}, {}
    correct_positions = 0
    
    for num, line in enumerate(open(sam)):
        if line.startswith('@'):
            continue
            
        data = line.strip().split()
        if data[9] == '*':
            continue
        start = int(data[3])
        if not start:
            continue
            
        read_name = data[0]
        read_type = 'forward' if int(data[8]) > 0 else 'backward'
        
        if start_positions and (read_name, read_type) in start_positions:
            start_ecoli_pos = start_positions[(read_name, read_type)]
            if np.abs(start_ecoli_pos - start) > 100:
                continue
                
            start = start_ecoli_pos
            
        if not start:
            continue

        errors = {}
        deletions = {}
        read = list(data[9])
        read_length = len(read)
        reference_region = reference[start - 1 : min(start - 1 + read_length, ref_length)]
        
        for pos, r in enumerate(reference_region):
            if r != read[pos]:
                if read[pos] == 'N' and not n_as_error:
                    deletions[start + pos] = (r, read[pos])
                else:
                    errors[start + pos] = (r, read[pos])
            else:
                correct_positions += 1
                
        if len(errors) > 0:
            n_errors[(read_name, read_type)] = errors
            
        if len(deletions) > 0:
            n_deletions[(read_name, read_type)] = deletions
    return n_errors, n_deletions, correct_positions


def read_names(sam):
    names = set()
    for num, line in enumerate(open(sam)):
        if line.startswith('@'):
            continue
            
        data = line.strip().split()
        if data[2] == '*' or data[5] == '*':
            continue
            
        start = int(data[3])
        if not start:
            continue
            
        read_name = data[0]
        read_type = 'forward' if int(data[8]) > 0 else 'backward'
        names.add((read_name, read_type))
    return names


def deleted(total_reads, sam):
    deleted_reads = total_reads.copy()
    for num, line in enumerate(open(sam)):
        if line.startswith('@'):
            continue
            
        data = line.strip().split()
        if data[2] == '*' or data[5] == '*':
            continue
            
        start = int(data[3])
        if not start:
            continue
            
        read_name = data[0]
        read_type = 'forward' if int(data[8]) > 0 else 'backward'
        if (read_name, read_type) in total_reads:
            deleted_reads.remove((read_name, read_type))
    return deleted_reads


def deleted_correct_positions(errors, deletions, deleted_reads, sam):
    n = 0
    for num, line in enumerate(open(sam)):
        if line.startswith('@'):
            continue
            
        data = line.strip().split()
        if data[2] == '*' or data[5] == '*':
            continue
            
        start = int(data[3])
        if not start:
            continue
            
        read_name = data[0]
        read_type = 'forward' if int(data[8]) > 0 else 'backward'
        read = list(data[9])
        
        if (read_name, read_type) in deleted_reads:
            read_length = len(read)
            if (read_name, read_type) not in errors:
                n += read_length
                continue
                
            errors_n = len(errors[(read_name, read_type)])
            n += (read_length - errors_n)
            
        elif (read_name, read_type) in deletions:
            errors_positions = errors[(read_name, read_type)] if (read_name, read_type) in errors else {}
            for pos in deletions[(read_name, read_type)]:
                if pos not in errors_positions:
                    n += 1
    return n

# %% [markdown]
# # Trimmomatic

# %%
# !trimmomatic PE data/ecoli_400K_err_1.fastq data/ecoli_400K_err_2.fastq \
trim1_paired.fq trim1_unpaired.fq trim2_paired.fq trim2_unpaired.fq \
LEADING:5 TRAILING:5 SLIDINGWINDOW:4:15 MINLEN:35
# Out:
# TrimmomaticPE: Started with arguments:
#  data/ecoli_400K_err_1.fastq data/ecoli_400K_err_2.fastq trim1_paired.fq trim1_unpaired.fq trim2_paired.fq trim2_unpaired.fq LEADING:5 TRAILING:5 SLIDINGWINDOW:4:15 MINLEN:35
# Multiple cores found: Using 4 threads
# Quality encoding detected as phred33
# Input Read Pairs: 1381602 Both Surviving: 1314087 (95,11%) Forward Only Surviving: 36625 (2,65%) Reverse Only Surviving: 26152 (1,89%) Dropped: 4738 (0,34%)
# TrimmomaticPE: Completed successfully

# %%
# !bwa mem data/MG1655-K12.first400K.fasta trim1_paired.fq trim2_paired.fq > trim_paired.sam
# Out:
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 109032 sequences (10000046 bp)...
# [M::process] read 109552 sequences (10000124 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 52822, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.25, 10.17)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 109032 reads in 3.460 CPU sec, 3.388 real sec
# [M::process] read 109748 sequences (10000159 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 53112, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.26, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 109552 reads in 3.167 CPU sec, 2.940 real sec
# [M::process] read 110184 sequences (10000136 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 53200, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.35, 10.17)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 109748 reads in 3.263 CPU sec, 3.129 real sec
# [M::process] read 110674 sequences (10000080 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 53438, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.36, 10.11)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 110184 reads in 2.859 CPU sec, 2.706 real sec
# [M::process] read 111610 sequences (10000107 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 53676, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.32, 10.19)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 110674 reads in 3.083 CPU sec, 2.951 real sec
# [M::process] read 110332 sequences (10000031 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 54111, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 221)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (179, 249)
# [M::mem_pestat] mean and std.dev: (214.23, 10.12)
# [M::mem_pestat] low and high boundaries for proper pairs: (165, 263)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 111610 reads in 3.321 CPU sec, 3.176 real sec
# [M::process] read 111160 sequences (10000009 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 53465, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.35, 10.16)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 110332 reads in 3.032 CPU sec, 2.882 real sec
# [M::process] read 111872 sequences (10000069 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 53922, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.39, 10.09)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 111160 reads in 3.621 CPU sec, 3.480 real sec
# [M::process] read 111878 sequences (10000190 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 54232, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.31, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 111872 reads in 3.015 CPU sec, 2.864 real sec
# [M::process] read 113266 sequences (10000036 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 54211, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.23, 10.14)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 111878 reads in 3.392 CPU sec, 3.252 real sec
# [M::process] read 112038 sequences (10000014 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 54862, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.36, 10.16)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 113266 reads in 3.056 CPU sec, 2.903 real sec
# [M::process] read 109106 sequences (10000148 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 54275, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.36, 10.13)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 112038 reads in 3.216 CPU sec, 3.061 real sec
# [M::process] read 108334 sequences (10000075 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 52845, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.28, 10.19)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 109106 reads in 2.988 CPU sec, 2.840 real sec
# [M::process] read 107532 sequences (10000135 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 52527, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.31, 10.10)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 108334 reads in 2.886 CPU sec, 2.743 real sec
# [M::process] read 106940 sequences (10000059 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 52128, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.42, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 107532 reads in 3.445 CPU sec, 3.302 real sec
# [M::process] read 106390 sequences (10000148 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 51857, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.36, 10.14)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 106940 reads in 2.918 CPU sec, 2.761 real sec
# [M::process] read 106512 sequences (10000045 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 51567, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.25, 10.17)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 106390 reads in 2.968 CPU sec, 2.828 real sec
# [M::process] read 106508 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 51595, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.30, 10.12)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 106512 reads in 2.888 CPU sec, 2.736 real sec
# [M::process] read 106630 sequences (10000097 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 51580, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 221)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (179, 249)
# [M::mem_pestat] mean and std.dev: (214.26, 10.08)
# [M::mem_pestat] low and high boundaries for proper pairs: (165, 263)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 106508 reads in 2.934 CPU sec, 2.772 real sec
# [M::process] read 106206 sequences (10000108 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 51701, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.24, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 106630 reads in 2.878 CPU sec, 2.717 real sec
# [M::process] read 105886 sequences (10000122 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 51460, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.31, 10.16)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 106206 reads in 2.895 CPU sec, 2.737 real sec
# [M::process] read 105670 sequences (10000022 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 51287, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.28, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 105886 reads in 2.906 CPU sec, 2.740 real sec
# [M::process] read 105478 sequences (10000022 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 51150, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.26, 10.16)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 105670 reads in 2.934 CPU sec, 2.767 real sec
# [M::process] read 15636 sequences (1488812 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 51099, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.26, 10.13)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 105478 reads in 2.901 CPU sec, 2.790 real sec
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 7576, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.29, 10.30)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 15636 reads in 0.627 CPU sec, 0.499 real sec
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem data/MG1655-K12.first400K.fasta trim1_paired.fq trim2_paired.fq
# [main] Real time: 71.249 sec; CPU: 74.763 sec

# %%
raw_errors, raw_deletions, raw_correct_positions = cnt_err_del('ecoli_400.sam', 'data/MG1655-K12.first400K.fasta')

# %%
trim_errors, trim_deletions, trim_correct_positions = cnt_err_del('trim_paired.sam', 
                                                                  'data/MG1655-K12.first400K.fasta')

# %%
total_raw_errors = 0
for positions in raw_errors.values():
    total_raw_errors += len(positions)
total_trim_errors = 0
for positions in trim_errors.values():
    total_trim_errors += len(positions)
    
result = pd.DataFrame(columns=['Error in corrected reads', 'Correct base in corrected reads', 
                               'Base is absent in corrected reads'], 
                      index=['Error in raw data', 'Correct base in raw data'])

result.loc['Error in raw data', 'Error in corrected reads'] = f'{total_trim_errors} ({total_trim_errors / total_raw_errors * 100:.3f}%)'

result.loc['Error in raw data', 'Correct base in corrected reads'] = f'0'

result.loc['Error in raw data', 'Base is absent in corrected reads'] = f'{total_raw_errors - total_trim_errors} ({(total_raw_errors - total_trim_errors) / total_raw_errors * 100:.3f}%)'

result.loc['Correct base in raw data', 'Error in corrected reads'] = f'0'

result.loc['Correct base in raw data', 'Correct base in corrected reads'] = f'{trim_correct_positions} ({trim_correct_positions / raw_correct_positions * 100:.3f}%)'

result.loc['Correct base in raw data', 'Base is absent in corrected reads'] = f'{raw_correct_positions - trim_correct_positions} ({(raw_correct_positions - trim_correct_positions) / raw_correct_positions * 100:.3f}%)'

# %%
result
# Out:
#                          Error in corrected reads  \
# Error in raw data                1389165 (9.354%)
# Correct base in raw data                        0
#
#                          Correct base in corrected reads  \
# Error in raw data                                      0
# Correct base in raw data             239971114 (91.883%)
#
#                          Base is absent in corrected reads
# Error in raw data                       13462255 (90.646%)
# Correct base in raw data                 21197833 (8.117%)

# %% [markdown]
# # Spades

# %%
def spades_table(errors1, errors2, deletions2, sam1, sam2, good1, good2):

    first_reads = read_names(sam1)
    second_deleted_reads = deleted(first_reads, sam2)
    
    total_reads = len(first_reads)
    deleted_reads = len(second_deleted_reads)
    n_errors = 0
    corrected_errors = 0
    deleted_errors = 0
    
    for (read, read_type), positions in errors1.items():
        n = len(positions)
        n_errors += n
        if (read, read_type) in second_deleted_reads:
            deleted_errors += n
            continue
            
        del_positions = deletions2[(read, read_type)] if (read, read_type) in deletions2 else {}
        err_positions = errors2[(read, read_type)] if (read, read_type) in errors2 else {}
        for pos in positions.keys():
            if pos in del_positions:
                deleted_errors += 1
            elif pos not in err_positions:
                corrected_errors += 1
            
    new_errors = 0
    for (read, read_type), positions in errors2.items():
        err_positions = errors1[(read, read_type)] if (read, read_type) in errors1 else {}
        for pos in positions.keys():
            if pos not in err_positions:
                new_errors += 1
    deleted_good_n = deleted_correct_positions(errors1, deletions2, second_deleted_reads, sam1)
    
    result = pd.DataFrame(columns=['Error in corrected reads', 'Correct base in corrected reads', 
                                   'Base is absent in corrected reads'], 
                          index=['Error in raw data', 'Correct base in raw data'])
    
    result.loc['Error in raw data', 'Error in corrected reads'] = f'{n_errors - deleted_errors - corrected_errors} ({(n_errors - deleted_errors - corrected_errors) / n_errors * 100:.3f}%)'
    
    result.loc['Error in raw data', 'Correct base in corrected reads'] = f'{corrected_errors} ({corrected_errors / n_errors * 100:.3f}%)'
    
    result.loc['Error in raw data', 'Base is absent in corrected reads'] = f'{deleted_errors} ({deleted_errors / n_errors * 100:.3f}%)'
    
    result.loc['Correct base in raw data', 'Error in corrected reads'] = f'{new_errors} ({new_errors / good1 * 100:.3f}%)'
    
    result.loc['Correct base in raw data', 'Correct base in corrected reads'] = f'{good1 - deleted_good_n - new_errors} ({(good1 - deleted_good_n - new_errors) / good1 * 100:.3f}%)'
    
    result.loc['Correct base in raw data', 'Base is absent in corrected reads'] = f'{deleted_good_n} ({deleted_good_n / good1 * 100:.3f}%)'
    return result

# %%
def read_start(sam):
    read2position = {}
    for num, line in enumerate(open(sam)):
        if line.startswith('@'):
            continue
            
        data = line.strip().split()
        if data[2] == '*' or data[5] == '*':
            continue
            
        start = int(data[3])
        if not start:
            continue
            
        read_name = data[0]
        read_type = 'forward' if int(data[8]) > 0 else 'backward'
        read2position[(read_name, read_type)] = start
    return read2position

# %%
# !spades.py -1 data/ecoli_400K_err_1.fastq -2 data/ecoli_400K_err_2.fastq -o spades_ecoli --only-error-correction \
--threads 6
# Out:
# == Warning ==  No assembly mode was sepcified! If you intend to assemble high-coverage multi-cell/isolate data, use '--isolate' option.
#
#
# Command line: /home/alex/anaconda3/bin/spades.py	-1	/home/alex/PycharmProjects/NGS/homework_4/data/ecoli_400K_err_1.fastq	-2	/home/alex/PycharmProjects/NGS/homework_4/data/ecoli_400K_err_2.fastq	-o	/home/alex/PycharmProjects/NGS/homework_4/spades_ecoli	--only-error-correction	--threads	6
#
# System information:
#   SPAdes version: 3.14.0
#   Python version: 3.7.4
#   OS: Linux-5.4.0-33-generic-x86_64-with-debian-bullseye-sid
#
# Output dir: /home/alex/PycharmProjects/NGS/homework_4/spades_ecoli
# Mode: ONLY read error correction (without assembling)
# Debug mode is turned OFF
#
# Dataset parameters:
#   Standard mode
#   For multi-cell/isolate data we recommend to use '--isolate' option; for single-cell MDA data use '--sc'; for metagenomic data use '--meta'; for RNA-Seq use '--rna'.
#   Reads:
#     Library number: 1, library type: paired-end
#       orientation: fr
#       left reads: ['/home/alex/PycharmProjects/NGS/homework_4/data/ecoli_400K_err_1.fastq']
#       right reads: ['/home/alex/PycharmProjects/NGS/homework_4/data/ecoli_400K_err_2.fastq']
#       interlaced reads: not specified
#       single reads: not specified
#       merged reads: not specified
# Read error correction parameters:
#   Iterations: 1
#   PHRED offset will be auto-detected
#   Corrected reads will be compressed
# Other parameters:
#   Dir for temp files: /home/alex/PycharmProjects/NGS/homework_4/spades_ecoli/tmp
#   Threads: 6
#   Memory limit (in Gb): 10
#
#
# ======= SPAdes pipeline started. Log can be found here: /home/alex/PycharmProjects/NGS/homework_4/spades_ecoli/spades.log
#
#
# ===== Read error correction started.
#
#
# ===== Read error correction started.
#
#
# == Running: /home/alex/anaconda3/bin/spades-hammer /home/alex/PycharmProjects/NGS/homework_4/spades_ecoli/corrected/configs/config.info
#
#   0:00:00.000     4M / 11M   INFO    General                 (main.cpp                  :  75)   Starting BayesHammer, built from N/A, git revision N/A
#   0:00:00.000     4M / 11M   INFO    General                 (main.cpp                  :  76)   Loading config from /home/alex/PycharmProjects/NGS/homework_4/spades_ecoli/corrected/configs/config.info
#   0:00:00.002     4M / 11M   INFO    General                 (main.cpp                  :  78)   Maximum # of threads to use (adjusted due to OMP capabilities): 6
#   0:00:00.002     4M / 11M   INFO    General                 (memory_limit.cpp          :  49)   Memory limit set to 10 Gb
#   0:00:00.002     4M / 11M   INFO    General                 (main.cpp                  :  86)   Trying to determine PHRED offset
#   0:00:00.002     4M / 11M   INFO    General                 (main.cpp                  :  92)   Determined value is 33
#   0:00:00.002     4M / 11M   INFO    General                 (hammer_tools.cpp          :  38)   Hamming graph threshold tau=1, k=21, subkmer positions = [ 0 10 ]
#   0:00:00.002     4M / 11M   INFO    General                 (main.cpp                  : 113)   Size of aux. kmer data 24 bytes
#      === ITERATION 0 begins ===
#   0:00:00.003     4M / 11M   INFO   K-mer Index Building     (kmer_index_builder.hpp    : 301)   Building kmer index
#   0:00:00.003     4M / 11M   INFO    General                 (kmer_index_builder.hpp    : 117)   Splitting kmer instances into 96 files using 6 threads. This might take a while.
#   0:00:00.003     4M / 11M   INFO    General                 (file_limit.hpp            :  32)   Open file limit set to 1024
#   0:00:00.003     4M / 11M   INFO    General                 (kmer_splitters.hpp        :  89)   Memory available for splitting buffers: 0.555522 Gb
#   0:00:00.003     4M / 11M   INFO    General                 (kmer_splitters.hpp        :  97)   Using cell size of 699050
#   0:00:00.005     4G / 4G    INFO   K-mer Splitting          (kmer_data.cpp             :  97)   Processing /home/alex/PycharmProjects/NGS/homework_4/data/ecoli_400K_err_1.fastq
#   0:00:10.460     4G / 4G    INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 1381602 reads
#   0:00:10.460     4G / 4G    INFO   K-mer Splitting          (kmer_data.cpp             :  97)   Processing /home/alex/PycharmProjects/NGS/homework_4/data/ecoli_400K_err_2.fastq
#   0:00:17.736     4G / 4G    INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 2763204 reads
#   0:00:17.736     4G / 4G    INFO   K-mer Splitting          (kmer_data.cpp             : 112)   Total 2763204 reads processed
#   0:00:17.886   109M / 2G    INFO    General                 (kmer_index_builder.hpp    : 120)   Starting k-mer counting.
#   0:00:18.211   109M / 2G    INFO    General                 (kmer_index_builder.hpp    : 127)   K-mer counting done. There are 13488952 kmers in total.
#   0:00:18.211   109M / 2G    INFO    General                 (kmer_index_builder.hpp    : 133)   Merging temporary buckets.
#   0:00:18.307   109M / 2G    INFO   K-mer Index Building     (kmer_index_builder.hpp    : 314)   Building perfect hash indices
#   0:00:19.164   115M / 2G    INFO    General                 (kmer_index_builder.hpp    : 150)   Merging final buckets.
#   0:00:19.661   115M / 2G    INFO   K-mer Index Building     (kmer_index_builder.hpp    : 336)   Index built. Total 6263040 bytes occupied (3.71447 bits per kmer).
#   0:00:19.695   115M / 2G    INFO   K-mer Counting           (kmer_data.cpp             : 351)   Arranging kmers in hash map order
#   0:00:20.428   333M / 2G    INFO    General                 (main.cpp                  : 148)   Clustering Hamming graph.
#   0:00:49.913   333M / 2G    INFO    General                 (main.cpp                  : 155)   Extracting clusters
#   0:00:55.909   320M / 2G    INFO    General                 (main.cpp                  : 167)   Clustering done. Total clusters: 2187352
#   0:00:55.916   208M / 2G    INFO   K-mer Counting           (kmer_data.cpp             : 371)   Collecting K-mer information, this takes a while.
#   0:00:56.045   528M / 2G    INFO   K-mer Counting           (kmer_data.cpp             : 377)   Processing /home/alex/PycharmProjects/NGS/homework_4/data/ecoli_400K_err_1.fastq
#   0:01:27.191   462M / 2G    INFO   K-mer Counting           (kmer_data.cpp             : 377)   Processing /home/alex/PycharmProjects/NGS/homework_4/data/ecoli_400K_err_2.fastq
#   0:01:58.459   462M / 2G    INFO   K-mer Counting           (kmer_data.cpp             : 384)   Collection done, postprocessing.
#   0:01:58.517   462M / 2G    INFO   K-mer Counting           (kmer_data.cpp             : 398)   There are 13488952 kmers in total. Among them 9831116 (72.8827%) are singletons.
#   0:01:58.517   462M / 2G    INFO    General                 (main.cpp                  : 173)   Subclustering Hamming graph
#   0:02:02.492   464M / 2G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 649)   Subclustering done. Total 1 non-read kmers were generated.
#   0:02:02.493   464M / 2G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 650)   Subclustering statistics:
#   0:02:02.493   464M / 2G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 651)     Total singleton hamming clusters: 1393328. Among them 2580 (0.185168%) are good
#   0:02:02.493   464M / 2G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 652)     Total singleton subclusters: 4146. Among them 4142 (99.9035%) are good
#   0:02:02.493   464M / 2G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 653)     Total non-singleton subcluster centers: 855746. Among them 836834 (97.79%) are good
#   0:02:02.493   464M / 2G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 654)     Average size of non-trivial subcluster: 14.1346 kmers
#   0:02:02.493   464M / 2G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 655)     Average number of sub-clusters per non-singleton cluster: 1.08295
#   0:02:02.493   464M / 2G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 656)     Total solid k-mers: 843556
#   0:02:02.494   464M / 2G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 657)     Substitution probabilities: [4,4]((0.925366,0.0417851,0.0246901,0.00815845),(0.0168258,0.960386,0.0122683,0.0105199),(0.0104921,0.0122447,0.960405,0.016858),(0.00814236,0.0246651,0.0417487,0.925444))
#   0:02:02.497   464M / 2G    INFO    General                 (main.cpp                  : 178)   Finished clustering.
#   0:02:02.497   464M / 2G    INFO    General                 (main.cpp                  : 197)   Starting solid k-mers expansion in 6 threads.
#   0:02:23.677   461M / 2G    INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 0 produced 45116 new k-mers.
#   0:02:44.864   457M / 2G    INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 1 produced 1684 new k-mers.
#   0:03:06.171   457M / 2G    INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 2 produced 63 new k-mers.
#   0:03:32.174   457M / 2G    INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 3 produced 32 new k-mers.
#   0:04:03.383   457M / 2G    INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 4 produced 0 new k-mers.
#   0:04:03.383   457M / 2G    INFO    General                 (main.cpp                  : 222)   Solid k-mers finalized
#   0:04:03.384   457M / 2G    INFO    General                 (hammer_tools.cpp          : 222)   Starting read correction in 6 threads.
#   0:04:03.384   457M / 2G    INFO    General                 (hammer_tools.cpp          : 235)   Correcting pair of reads: /home/alex/PycharmProjects/NGS/homework_4/data/ecoli_400K_err_1.fastq and /home/alex/PycharmProjects/NGS/homework_4/data/ecoli_400K_err_2.fastq
#   0:04:06.078   910M / 2G    INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 0 of 600000 reads.
#   0:04:18.888   930M / 2G    INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 0
#   0:04:20.832   930M / 2G    INFO    General                 (hammer_tools.cpp          : 187)   Written batch 0
#   0:04:23.032   930M / 2G    INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 1 of 600000 reads.
#   0:04:35.758   943M / 2G    INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 1
#   0:04:37.490   943M / 2G    INFO    General                 (hammer_tools.cpp          : 187)   Written batch 1
#   0:04:38.116   943M / 2G    INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 2 of 181602 reads.
#   0:04:42.920   946M / 2G    INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 2
#   0:04:43.721   946M / 2G    INFO    General                 (hammer_tools.cpp          : 187)   Written batch 2
#   0:04:43.914   786M / 2G    INFO    General                 (hammer_tools.cpp          : 276)   Correction done. Changed 883912 bases in 651938 reads.
#   0:04:43.915   786M / 2G    INFO    General                 (hammer_tools.cpp          : 277)   Failed to correct 21928 bases out of 252262696.
#   0:04:43.957   354M / 2G    INFO    General                 (main.cpp                  : 255)   Saving corrected dataset description to /home/alex/PycharmProjects/NGS/homework_4/spades_ecoli/corrected/corrected.yaml
#   0:04:43.962   354M / 2G    INFO    General                 (main.cpp                  : 262)   All done. Exiting.
#
# ===== Read error correction finished.
#
#
# ===== corrected reads compression started.
#
#
# == Running: /home/alex/anaconda3/bin/python /home/alex/anaconda3/share/spades/spades_pipeline/scripts/compress_all.py --input_file /home/alex/PycharmProjects/NGS/homework_4/spades_ecoli/corrected/corrected.yaml --ext_python_modules_home /home/alex/anaconda3/share/spades --max_threads 6 --output_dir /home/alex/PycharmProjects/NGS/homework_4/spades_ecoli/corrected --gzip_output
#
# == Compressing corrected reads (with gzip)
#
# ===== corrected reads compression finished.
#
#
# ===== Read error correction finished.
#
#
# ===== Breaking scaffolds started.
#
#
# == Running: /home/alex/anaconda3/bin/python /home/alex/anaconda3/share/spades/spades_pipeline/scripts/breaking_scaffolds_script.py --result_scaffolds_filename /home/alex/PycharmProjects/NGS/homework_4/spades_ecoli/scaffolds.fasta --misc_dir /home/alex/PycharmProjects/NGS/homework_4/spades_ecoli/misc --threshold_for_breaking_scaffolds 3
#
#
# ===== Breaking scaffolds finished.
#
#
# ===== Terminate started.
#
#
# ===== Terminate finished.
#
#  * Corrected reads are in /home/alex/PycharmProjects/NGS/homework_4/spades_ecoli/corrected/
#
# ======= SPAdes pipeline finished.
#
# SPAdes log can be found here: /home/alex/PycharmProjects/NGS/homework_4/spades_ecoli/spades.log
#
# Thank you for using SPAdes!

# %%
# !bwa mem data/MG1655-K12.first400K.fasta spades_ecoli/corrected/ecoli_400K_err_1.00.0_0.cor.fastq.gz \
spades_ecoli/corrected/ecoli_400K_err_2.00.0_0.cor.fastq.gz > spades_ecoli.sam
# Out:
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 100000 sequences (10000000 bp)...
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48352, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.27, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.047 CPU sec, 2.854 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48401, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.22, 10.16)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.239 CPU sec, 2.898 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48399, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.35, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.944 CPU sec, 2.617 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48377, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.38, 10.14)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.834 CPU sec, 2.544 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48371, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.32, 10.17)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.847 CPU sec, 2.547 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48414, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.36, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.852 CPU sec, 2.552 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48317, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 221)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (179, 249)
# [M::mem_pestat] mean and std.dev: (214.24, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (165, 263)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.850 CPU sec, 2.548 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48419, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.34, 10.14)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.828 CPU sec, 2.537 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48404, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.40, 10.07)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.821 CPU sec, 2.527 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48388, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.36, 10.14)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.840 CPU sec, 2.537 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48318, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.24, 10.18)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.857 CPU sec, 2.544 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48338, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.30, 10.14)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.846 CPU sec, 2.540 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48261, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.35, 10.16)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.830 CPU sec, 2.550 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48332, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.35, 10.13)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.841 CPU sec, 2.551 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48379, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.31, 10.17)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.839 CPU sec, 2.553 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48396, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.29, 10.11)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.834 CPU sec, 2.569 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48371, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.45, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.830 CPU sec, 2.532 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48421, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.38, 10.13)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.794 CPU sec, 2.490 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48381, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 221)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (179, 249)
# [M::mem_pestat] mean and std.dev: (214.26, 10.13)
# [M::mem_pestat] low and high boundaries for proper pairs: (165, 263)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.815 CPU sec, 2.507 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48426, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.32, 10.17)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.181 CPU sec, 2.876 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48336, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.24, 10.13)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.311 CPU sec, 2.893 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48423, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.24, 10.11)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.777 CPU sec, 2.502 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48403, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.32, 10.14)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.761 CPU sec, 2.485 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48382, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.31, 10.16)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 3.621 CPU sec, 3.291 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48355, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.31, 10.12)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.884 CPU sec, 2.599 real sec
# [M::process] read 100000 sequences (10000000 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48327, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.25, 10.16)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.897 CPU sec, 2.608 real sec
# [M::process] read 16054 sequences (1605400 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 48388, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.28, 10.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100000 reads in 2.665 CPU sec, 2.533 real sec
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 7766, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (207, 214, 222)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (177, 252)
# [M::mem_pestat] mean and std.dev: (214.28, 10.28)
# [M::mem_pestat] low and high boundaries for proper pairs: (162, 267)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 16054 reads in 0.553 CPU sec, 0.451 real sec
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem data/MG1655-K12.first400K.fasta spades_ecoli/corrected/ecoli_400K_err_1.00.0_0.cor.fastq.gz spades_ecoli/corrected/ecoli_400K_err_2.00.0_0.cor.fastq.gz
# [main] Real time: 72.467 sec; CPU: 79.656 sec

# %%
start_positions = read_start('ecoli_400.sam')

# %%
spades_errors, spades_deletions, spades_correct_positions = cnt_err_del('spades_ecoli.sam',
                                                                        'data/MG1655-K12.first400K.fasta',
                                                                        start_positions=start_positions)

# %%
result = spades_table(raw_errors, spades_errors, spades_deletions, 'ecoli_400.sam', 'spades_ecoli.sam', 
                      raw_correct_positions, spades_correct_positions)

# %%
result
# Out:
#                          Error in corrected reads  \
# Error in raw data               7605795 (51.213%)
# Correct base in raw data           26086 (0.010%)
#
#                          Correct base in corrected reads  \
# Error in raw data                        826684 (5.566%)
# Correct base in raw data             241818403 (92.591%)
#
#                          Base is absent in corrected reads
# Error in raw data                        6418941 (43.221%)
# Correct base in raw data                 19324458 (7.399%)

# %%
# вывод: кажется, что Trimmamatic справляется лучше, так как TP значительно выше, чем у Spades, TN мерно 
# одинаковы.
